# %%
# DEPENDENCIES & SETUP #
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt

# READ IN DATA #
# File to Load (Remember to Change These)
file_to_load = "degrees-that-pay-back.csv"

# Read Purchasing File and store into Pandas data frame
degrees_data = pd.read_csv(file_to_load)
degrees_data.head()
#degrees_data.dtypes
# Out:
#      Undergraduate Major Starting Median Salary Mid-Career Median Salary  \
# 0             Accounting             $46,000.00               $77,100.00
# 1  Aerospace Engineering             $57,700.00              $101,000.00
# 2            Agriculture             $42,600.00               $71,900.00
# 3           Anthropology             $36,800.00               $61,500.00
# 4           Architecture             $41,600.00               $76,800.00
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $42,200.00                        $56,100.00
# ...

# %%
#Change Column Names

degrees_data.columns = ['degree','start','midcareer','starttomid_chng','midcareer_p10','midcareer_p25','midcareer_p75','midcareer_p90']

degrees_data.head()

#degrees_data.dtypes
# Out:
#                   degree       start    midcareer  starttomid_chng  \
# 0             Accounting  $46,000.00   $77,100.00             67.6
# 1  Aerospace Engineering  $57,700.00  $101,000.00             75.0
# 2            Agriculture  $42,600.00   $71,900.00             68.8
# 3           Anthropology  $36,800.00   $61,500.00             67.1
# 4           Architecture  $41,600.00   $76,800.00             84.6
#
#   midcareer_p10 midcareer_p25 midcareer_p75 midcareer_p90
# 0    $42,200.00    $56,100.00   $108,000.00   $152,000.00
# 1    $64,300.00    $82,100.00   $127,000.00   $161,000.00
# 2    $36,300.00    $52,100.00    $96,300.00   $150,000.00
# 3    $33,800.00    $45,500.00    $89,300.00   $138,000.00
# 4    $50,600.00    $62,200.00    $97,000.00   $136,000.00

# %%
#Change variables from objects to integers
column_names = ['midcareer_p10','midcareer_p25','midcareer_p75','midcareer_p90']

for column in column_names:
    degrees_data[column] = degrees_data[column].str.replace("$","")
    degrees_data[column] = degrees_data[column].str.replace(",","")
    degrees_data[column] = pd.to_numeric(degrees_data[column])

# %%
degrees_data.head()
# Out:
#                   degree       start    midcareer  starttomid_chng  \
# 0             Accounting  $46,000.00   $77,100.00             67.6
# 1  Aerospace Engineering  $57,700.00  $101,000.00             75.0
# 2            Agriculture  $42,600.00   $71,900.00             68.8
# 3           Anthropology  $36,800.00   $61,500.00             67.1
# 4           Architecture  $41,600.00   $76,800.00             84.6
#
#    midcareer_p10  midcareer_p25  midcareer_p75  midcareer_p90
# 0        42200.0        56100.0       108000.0       152000.0
# 1        64300.0        82100.0       127000.0       161000.0
# 2        36300.0        52100.0        96300.0       150000.0
# 3        33800.0        45500.0        89300.0       138000.0
# 4        50600.0        62200.0        97000.0       136000.0

# %%
#Overall Descriptive Statitics - All Majors combined
degrees_data.describe()
# Out:
#        starttomid_chng  midcareer_p10  midcareer_p25  midcareer_p75  \
# count        50.000000      50.000000      50.000000      50.000000
# mean         69.274000   43408.000000   55988.000000  102138.000000
# std          17.909908   12000.779567   13936.951911   20636.789914
# min          23.400000   26700.000000   36500.000000   70500.000000
# 25%          59.125000   34825.000000   44975.000000   83275.000000
# 50%          67.800000   39400.000000   52450.000000   99400.000000
# 75%          82.425000   49850.000000   63700.000000  118750.000000
# max         103.500000   71900.000000   87300.000000  145000.000000
#
#        midcareer_p90
# count      50.000000
# mean   142766.000000
# std     27851.249267
# min     96400.000000
# 25%    124250.000000
# 50%    145500.000000
# 75%    161750.000000
# max    210000.000000

# %%
degrees_data = degrees_data.reset_index()
#degrees_data.head(10)

# %%
#Sort by Starting salary
sorted_start = degrees_data.sort_values('start', ascending = False)
sorted_start.head()
# Out:
#     index                  degree       start    midcareer  starttomid_chng  \
# 43     43     Physician Assistant  $74,300.00   $91,700.00             23.4
# 8       8    Chemical Engineering  $63,200.00  $107,000.00             69.3
# 12     12    Computer Engineering  $61,400.00  $105,000.00             71.0
# 19     19  Electrical Engineering  $60,900.00  $103,000.00             69.1
# 38     38  Mechanical Engineering  $57,900.00   $93,600.00             61.7
#
#     midcareer_p10  midcareer_p25  midcareer_p75  midcareer_p90
# 43        66400.0        75200.0       108000.0       124000.0
# 8         71900.0        87300.0       143000.0       194000.0
# 12        66100.0        84100.0       135000.0       162000.0
# 19        69300.0        83800.0       130000.0       168000.0
# 38        63700.0        76200.0       120000.0       163000.0

# %%
sorted_start1 = pd.DataFrame(sorted_start, columns=["degree", "start"])
sorted_start1.head()
# Out:
#                     degree       start
# 43     Physician Assistant  $74,300.00
# 8     Chemical Engineering  $63,200.00
# 12    Computer Engineering  $61,400.00
# 19  Electrical Engineering  $60,900.00
# 38  Mechanical Engineering  $57,900.00

# %%
#Graph Degress sorted by Starting Salary
fig = plt.figure(figsize=(8,12))

x = sorted_start['start']
y = len(sorted_start.index) - sorted_start.index
labels = sorted_start1['degree']

plt.scatter(x, y, color='g', label = 'Starting Median Salary')
plt.yticks(y, labels)

plt.xlabel('US $')
plt.ylabel('')
plt.title('Starting Median Salary by Degree')
plt.legend(loc=2)
plt.show()

# %%
# Create a bar chart based off of the group series from before
sorted_start_chart = sorted_start.plot(kind='bar')

# Set the xlabel and ylabel using class methods
sorted_start_chart.set_xlabel("College Degrees")
sorted_start_chart.set_ylabel("Starting Median Salary")


plt.show()
plt.tight_layout()

############################################################

# %%
#Sort by midcareer salary
sorted_midcareer = degrees_data.sort_values('midcareer', ascending = False)
#sorted_midcareer.head()

sorted_midcareer1 = pd.DataFrame(sorted_midcareer, columns=["degree", "midcareer"])
sorted_midcareer1.head()
# Out:
#                     degree   midcareer
# 17               Economics  $98,600.00
# 44                 Physics  $97,300.00
# 13        Computer Science  $95,500.00
# 30  Industrial Engineering  $94,700.00
# 38  Mechanical Engineering  $93,600.00

# %%
#Graph Degress sorted by Starting Salary

fig = plt.figure(figsize=(8,12))

x = sorted_midcareer1['midcareer']
y = len(sorted_midcareer1.index) - sorted_midcareer1.index
labels = sorted_midcareer1['degree']

plt.scatter(x, y, color='g', label = 'Mid-Career Median Salary')
plt.yticks(y, labels)

plt.xlabel('US $')
plt.ylabel('')
plt.title('Mid-Career Median Salary by Degree')
plt.legend(loc=2)
plt.show()

# %%
# Create a bar chart based off of the group series from before
sorted_start_chart = sorted_start1.plot(kind='bar')

# Set the xlabel and ylabel using class methods
sorted_start_chart.set_xlabel("College Degrees")
sorted_start_chart.set_ylabel("Starting Median Salary")


plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-944cfebd0335> in <module>
#       1 # Create a bar chart based off of the group series from before
# ----> 2 sorted_start_chart = sorted_start1.plot(kind='bar')
#       3
#       4 # Set the xlabel and ylabel using class methods
#       5 sorted_start_chart.set_xlabel("College Degrees")
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# ...

# %%
#Sort by Starting salary to MidCareer Change 
sorted_starttomid_chng = degrees_data.sort_values('starttomid_chng', ascending = False)
sorted_starttomid_chng.head()
# Out:
#     level_0  index                   degree       start   midcareer  \
# 37       37     37                     Math  $45,400.00  $92,400.00
# 42       42     42               Philosophy  $39,900.00  $81,200.00
# 33       33     33  International Relations  $40,900.00  $80,900.00
# 17       17     17                Economics  $50,100.00  $98,600.00
# 36       36     36                Marketing  $40,800.00  $79,600.00
#
#     starttomid_chng  midcareer_p10  midcareer_p25  midcareer_p75  \
# 37            103.5        45200.0        64200.0       128000.0
# 42            103.5        35500.0        52800.0       127000.0
# 33             97.8        38200.0        56000.0       111000.0
# 17             96.8        50600.0        70600.0       145000.0
# 36             95.1        42100.0        55600.0       119000.0
#
#     midcareer_p90
# 37       183000.0
# 42       168000.0
# 33       157000.0
# 17       210000.0
# 36       175000.0

# %%
#Sort by midcareer_p90 salary
sorted_midcareer_p90 = degrees_data.sort_values('midcareer_p90', ascending = False)
sorted_midcareer_p90.head()
# Out:
#     level_0  index                degree    start  midcareer  starttomid_chng  \
# 12       12     17             Economics  50100.0    98600.0             96.8
# 15       15     22               Finance  47900.0    88300.0             84.3
# 1         1      8  Chemical Engineering  63200.0   107000.0             69.3
# 17       17     37                  Math  45400.0    92400.0            103.5
# 11       11     44               Physics  50300.0    97300.0             93.4
#
#     midcareer_p10  midcareer_p25  midcareer_p75  midcareer_p90
# 12        50600.0        70600.0       145000.0       210000.0
# 15        47200.0        62100.0       128000.0       195000.0
# 1         71900.0        87300.0       143000.0       194000.0
# 17        45200.0        64200.0       128000.0       183000.0
# 11        56000.0        74200.0       132000.0       178000.0
