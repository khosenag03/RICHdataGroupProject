# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# Read Degree File and Create DataFrame
Degree_File = pd.read_csv("degrees-that-pay-back.csv")
Degree_df = pd.DataFrame(Degree_File)

# Read Salaries by college type and Create DataFram
College_Type_File = pd.read_csv("salaries-by-college-type.csv")
College_Type_df = pd.DataFrame(College_Type_File)

#Read Salaries by Region file and Create DataFrame
Region_File = pd.read_csv("salaries-by-region.csv")
Region_df = pd.DataFrame(Region_File)

# %%
Degree_df.head()
# Out:
#      Undergraduate Major Starting Median Salary Mid-Career Median Salary  \
# 0             Accounting             $46,000.00               $77,100.00
# 1  Aerospace Engineering             $57,700.00              $101,000.00
# 2            Agriculture             $42,600.00               $71,900.00
# 3           Anthropology             $36,800.00               $61,500.00
# 4           Architecture             $41,600.00               $76,800.00
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $42,200.00                        $56,100.00
# 1                        $64,300.00                        $82,100.00
# 2                        $36,300.00                        $52,100.00
# 3                        $33,800.00                        $45,500.00
# 4                        $50,600.00                        $62,200.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                       $108,000.00                       $152,000.00
# 1                       $127,000.00                       $161,000.00
# 2                        $96,300.00                       $150,000.00
# 3                        $89,300.00                       $138,000.00
# 4                        $97,000.00                       $136,000.00

# %%
College_Type_df
# Out:
#                                            School Name  School Type  \
# 0          Massachusetts Institute of Technology (MIT)  Engineering
# 1             California Institute of Technology (CIT)  Engineering
# 2                                  Harvey Mudd College  Engineering
# 3         Polytechnic University of New York, Brooklyn  Engineering
# 4                                         Cooper Union  Engineering
# 5                Worcester Polytechnic Institute (WPI)  Engineering
# 6                     Carnegie Mellon University (CMU)  Engineering
# 7               Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                      Georgia Institute of Technology  Engineering
# 9                             Colorado School of Mines  Engineering
# 10                     Stevens Institute of Technology  Engineering
# 11              Illinois Institute of Technology (IIT)  Engineering
# 12                   Wentworth Institute of Technology  Engineering
# 13   Virginia Polytechnic Institute and State Unive...  Engineering
# 14           South Dakota School of Mines & Technology  Engineering
# 15   New Mexico Institute of Mining and Technology ...  Engineering
# 16             Rochester Institute of Technology (RIT)  Engineering
# 17         Embry-Riddle Aeronautical University (ERAU)  Engineering
# 18                  Tennessee Technological University  Engineering
# 19   University of Illinois at Urbana-Champaign (UIUC)        Party
# 20                University of Maryland, College Park        Party
# 21      University of California, Santa Barbara (UCSB)        Party
# 22                   University of Texas (UT) - Austin        Party
# 23       State University of New York (SUNY) at Albany        Party
# 24                          University of Florida (UF)        Party
# 25                    Louisiana State University (LSU)        Party
# 26                         University of Georgia (UGA)        Party
# 27                 Pennsylvania State University (PSU)        Party
# 28                      Arizona State University (ASU)        Party
# 29                Indiana University (IU), Bloomington        Party
# ..                                                 ...          ...
# 239          University of Alabama at Birmingham (UAB)        State
# 240                     University of Memphis (U of M)        State
# 241                       Boise State University (BSU)        State
# 242                    Missouri State University (MSU)        State
# 243           University of Wisconsin (UW) - La Crosse        State
# 244                       Appalachian State University        State
# 245             Virginia Commonwealth University (VCU)        State
# 246               University of Wisconsin (UW) - Stout        State
# 247                     East Carolina University (ECU)        State
# 248                          Utah Valley State College        State
# 249          University of Missouri - St. Louis (UMSL)        State
# 250                        Western Carolina University        State
# 251             University of Wisconsin (UW) - Oshkosh        State
# 252    State University of New York (SUNY) at Fredonia        State
# 253        University of Missouri - Kansas City (UMKC)        State
# 254          University of Wisconsin (UW) - Eau Claire        State
# 255                        Ball State University (BSU)        State
# 256  University of North Carolina at Wilmington (UNCW)        State
# 257       University of Wisconsin (UW) - Stevens Point        State
# 258                       University of Southern Maine        State
# 259                    Arkansas State University (ASU)        State
# 260                              Kent State University        State
# 261                    Tarleton State University (TSU)        State
# 262           University of Wisconsin (UW) - Green Bay        State
# 263                          Morehead State University        State
# 264                       Austin Peay State University        State
# 265                         Pittsburg State University        State
# 266                           Southern Utah University        State
# 267                Montana State University - Billings        State
# 268                       Black Hills State University        State
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0               $72,200.00              $126,000.00
# 1               $75,500.00              $123,000.00
# 2               $71,800.00              $122,000.00
# 3               $62,400.00              $114,000.00
# 4               $62,200.00              $114,000.00
# 5               $61,000.00              $114,000.00
# 6               $61,800.00              $111,000.00
# 7               $61,100.00              $110,000.00
# 8               $58,300.00              $106,000.00
# 9               $58,100.00              $106,000.00
# 10              $60,600.00              $105,000.00
# 11              $56,000.00               $97,800.00
# 12              $53,000.00               $96,700.00
# 13              $53,500.00               $95,400.00
# 14              $55,800.00               $93,400.00
# 15              $51,000.00               $93,400.00
# 16              $48,900.00               $84,600.00
# 17              $52,700.00               $80,700.00
# 18              $46,200.00               $80,000.00
# 19              $52,900.00               $96,100.00
# 20              $52,000.00               $95,000.00
# 21              $50,500.00               $95,000.00
# 22              $49,700.00               $93,900.00
# 23              $44,500.00               $92,200.00
# 24              $47,100.00               $87,900.00
# 25              $46,900.00               $87,800.00
# 26              $44,100.00               $86,000.00
# 27              $49,900.00               $85,700.00
# 28              $47,400.00               $84,100.00
# 29              $46,300.00               $84,000.00
# ..                     ...                      ...
# 239             $39,200.00               $70,100.00
# 240             $41,400.00               $69,700.00
# 241             $40,800.00               $69,500.00
# 242             $36,100.00               $69,500.00
# 243             $42,200.00               $69,300.00
# 244             $40,400.00               $69,100.00
# 245             $42,000.00               $68,400.00
# 246             $43,600.00               $68,300.00
# 247             $40,200.00               $67,500.00
# 248             $42,400.00               $67,100.00
# 249             $41,400.00               $67,100.00
# 250             $36,900.00               $66,600.00
# 251             $39,300.00               $66,400.00
# 252             $37,800.00               $66,200.00
# 253             $38,900.00               $65,800.00
# 254             $41,400.00               $64,800.00
# 255             $39,100.00               $64,500.00
# 256             $37,500.00               $64,400.00
# 257             $39,800.00               $64,000.00
# 258             $39,400.00               $63,600.00
# 259             $38,700.00               $63,300.00
# 260             $38,700.00               $62,600.00
# 261             $40,800.00               $62,400.00
# 262             $35,800.00               $60,600.00
# 263             $34,800.00               $60,600.00
# 264             $37,700.00               $59,200.00
# 265             $40,400.00               $58,200.00
# 266             $41,900.00               $56,500.00
# 267             $37,900.00               $50,600.00
# 268             $35,300.00               $43,900.00
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                          $76,800.00                        $99,200.00
# 1                                 NaN                       $104,000.00
# 2                                 NaN                        $96,000.00
# 3                          $66,800.00                        $94,300.00
# 4                                 NaN                        $80,200.00
# 5                          $80,000.00                        $91,200.00
# 6                          $63,300.00                        $80,100.00
# 7                          $71,600.00                        $85,500.00
# 8                          $67,200.00                        $85,200.00
# 9                          $62,200.00                        $87,900.00
# 10                         $68,700.00                        $81,900.00
# 11                         $56,100.00                        $77,400.00
# 12                         $55,200.00                        $74,000.00
# 13                         $50,600.00                        $71,400.00
# 14                         $71,500.00                        $81,900.00
# 15                                NaN                        $67,400.00
# 16                         $45,000.00                        $62,100.00
# 17                         $49,800.00                        $64,000.00
# 18                         $42,100.00                        $62,600.00
# 19                         $48,200.00                        $68,900.00
# 20                         $50,400.00                        $68,300.00
# 21                         $51,300.00                        $71,200.00
# 22                         $50,100.00                        $67,400.00
# 23                         $47,000.00                        $63,100.00
# 24                         $45,400.00                        $62,900.00
# 25                         $43,700.00                        $61,300.00
# 26                         $43,100.00                        $57,800.00
# 27                         $46,300.00                        $62,000.00
# 28                         $44,600.00                        $60,700.00
# 29                         $43,600.00                        $60,400.00
# ..                                ...                               ...
# 239                        $43,000.00                        $53,400.00
# 240                        $36,100.00                        $49,100.00
# 241                        $37,400.00                        $48,700.00
# 242                        $33,300.00                        $46,900.00
# 243                        $37,500.00                        $47,200.00
# 244                        $37,200.00                        $50,400.00
# 245                        $37,400.00                        $51,900.00
# 246                        $40,900.00                        $50,600.00
# 247                        $38,400.00                        $52,000.00
# 248                        $27,000.00                        $44,100.00
# 249                        $36,800.00                        $49,600.00
# 250                        $39,000.00                        $49,500.00
# 251                        $37,700.00                        $49,700.00
# 252                        $32,800.00                        $44,200.00
# 253                        $36,300.00                        $48,100.00
# 254                        $35,000.00                        $47,300.00
# 255                        $35,500.00                        $48,200.00
# 256                        $32,100.00                        $46,600.00
# 257                        $38,400.00                        $45,100.00
# 258                        $40,400.00                        $47,900.00
# 259                        $33,600.00                        $45,300.00
# 260                        $36,100.00                        $45,800.00
# 261                        $32,100.00                        $47,400.00
# 262                        $35,500.00                        $46,800.00
# 263                        $34,300.00                        $46,500.00
# 264                        $32,200.00                        $40,500.00
# 265                        $25,600.00                        $46,000.00
# 266                        $30,700.00                        $39,700.00
# 267                        $22,600.00                        $31,800.00
# 268                        $27,000.00                        $32,200.00
#
#     Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                         $168,000.00                       $220,000.00
# 1                         $161,000.00                               NaN
# 2                         $180,000.00                               NaN
# 3                         $143,000.00                       $190,000.00
# 4                         $142,000.00                               NaN
# 5                         $137,000.00                       $180,000.00
# 6                         $150,000.00                       $209,000.00
# 7                         $140,000.00                       $182,000.00
# 8                         $137,000.00                       $183,000.00
# 9                         $142,000.00                       $201,000.00
# 10                        $138,000.00                       $185,000.00
# 11                        $121,000.00                       $165,000.00
# 12                        $117,000.00                       $153,000.00
# 13                        $124,000.00                       $163,000.00
# 14                        $122,000.00                       $147,000.00
# 15                        $123,000.00                               NaN
# 16                        $112,000.00                       $159,000.00
# 17                        $106,000.00                       $142,000.00
# 18                         $99,500.00                       $121,000.00
# 19                        $132,000.00                       $177,000.00
# 20                        $126,000.00                       $166,000.00
# 21                        $129,000.00                       $173,000.00
# 22                        $129,000.00                       $188,000.00
# 23                        $135,000.00                       $209,000.00
# 24                        $120,000.00                       $172,000.00
# 25                        $120,000.00                       $165,000.00
# 26                        $118,000.00                       $164,000.00
# 27                        $117,000.00                       $160,000.00
# 28                        $114,000.00                       $163,000.00
# 29                        $119,000.00                       $178,000.00
# ..                                ...                               ...
# 239                        $91,400.00                       $125,000.00
# 240                        $93,500.00                       $127,000.00
# 241                        $87,500.00                       $110,000.00
# 242                       $102,000.00                       $134,000.00
# 243                        $93,100.00                       $133,000.00
# 244                        $90,800.00                       $115,000.00
# 245                       $100,000.00                       $123,000.00
# 246                        $91,600.00                       $136,000.00
# 247                        $98,700.00                       $151,000.00
# 248                        $84,900.00                       $110,000.00
# 249                        $97,600.00                       $144,000.00
# 250                        $94,400.00                       $133,000.00
# 251                        $90,100.00                       $138,000.00
# 252                        $93,300.00                       $181,000.00
# 253                        $95,800.00                       $124,000.00
# 254                        $93,100.00                       $125,000.00
# 255                        $89,300.00                       $128,000.00
# 256                        $97,100.00                       $129,000.00
# 257                        $95,400.00                       $128,000.00
# 258                        $85,700.00                       $117,000.00
# 259                        $83,900.00                       $118,000.00
# 260                        $87,000.00                       $124,000.00
# 261                        $80,400.00                       $126,000.00
# 262                        $81,800.00                       $102,000.00
# 263                        $72,000.00                        $91,300.00
# 264                        $73,900.00                        $96,200.00
# 265                        $84,600.00                       $117,000.00
# 266                        $78,400.00                       $116,000.00
# 267                        $78,500.00                        $98,900.00
# 268                        $60,900.00                        $87,600.00
#
# [269 rows x 8 columns]

# %%
College_Type_df.columns = ['School Name', 'School Type','str_sal', 'mid_car', 'mid_car_10p', 'mid_car25p', 'mid_car75p', 'mid_car90p']
College_Type_df.head()
# Out:
#                                     School Name  School Type     str_sal  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering  $72,200.00
# 1      California Institute of Technology (CIT)  Engineering  $75,500.00
# 2                           Harvey Mudd College  Engineering  $71,800.00
# 3  Polytechnic University of New York, Brooklyn  Engineering  $62,400.00
# 4                                  Cooper Union  Engineering  $62,200.00
#
#        mid_car mid_car_10p   mid_car25p   mid_car75p   mid_car90p
# 0  $126,000.00  $76,800.00   $99,200.00  $168,000.00  $220,000.00
# 1  $123,000.00         NaN  $104,000.00  $161,000.00          NaN
# 2  $122,000.00         NaN   $96,000.00  $180,000.00          NaN
# 3  $114,000.00  $66,800.00   $94,300.00  $143,000.00  $190,000.00
# 4  $114,000.00         NaN   $80,200.00  $142,000.00          NaN

# %%
Salary_Columns = ['str_sal', 'mid_car', 'mid_car_10p', 'mid_car25p', 'mid_car75p', 'mid_car90p']

for x in Salary_Columns:
    College_Type_df[x] = College_Type_df[x].str.replace('$',"")
    College_Type_df[x] = College_Type_df[x].str.replace(",","")
    College_Type_df[x] = pd.to_numeric(College_Type_df[x])
    
College_Type_df.head()
# Out:
#                                     School Name  School Type  str_sal  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering  72200.0
# 1      California Institute of Technology (CIT)  Engineering  75500.0
# 2                           Harvey Mudd College  Engineering  71800.0
# 3  Polytechnic University of New York, Brooklyn  Engineering  62400.0
# 4                                  Cooper Union  Engineering  62200.0
#
#     mid_car  mid_car_10p  mid_car25p  mid_car75p  mid_car90p
# 0  126000.0      76800.0     99200.0    168000.0    220000.0
# 1  123000.0          NaN    104000.0    161000.0         NaN
# 2  122000.0          NaN     96000.0    180000.0         NaN
# 3  114000.0      66800.0     94300.0    143000.0    190000.0
# 4  114000.0          NaN     80200.0    142000.0         NaN

# %%
College_Type_df.describe()
# Out:
#             str_sal        mid_car   mid_car_10p     mid_car25p  \
# count    269.000000     269.000000    231.000000     269.000000
# mean   46068.401487   83932.342007  44250.649351   60373.234201
# std     6412.616242   14336.191107   8719.612427   11381.348857
# min    34800.000000   43900.000000  22600.000000   31800.000000
# 25%    42000.000000   74000.000000  39000.000000   53200.000000
# 50%    44700.000000   81600.000000  43100.000000   58400.000000
# 75%    48300.000000   92200.000000  47400.000000   65100.000000
# max    75500.000000  134000.000000  80000.000000  104000.000000
#
#           mid_car75p     mid_car90p
# count     269.000000     231.000000
# mean   116275.092937  157705.627706
# std     22952.334054   34823.348157
# min     60900.000000   87600.000000
# 25%    100000.000000  136000.000000
# 50%    113000.000000  153000.000000
# 75%    126000.000000  170500.000000
# max    234000.000000  326000.000000

# %%
College_Type_clean = College_Type_df[['School Name', 'School Type', 'str_sal', 'mid_car25p', 'mid_car90p']]
College_Type_clean.head()
# Out:
#                                     School Name  School Type  str_sal  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering  72200.0
# 1      California Institute of Technology (CIT)  Engineering  75500.0
# 2                           Harvey Mudd College  Engineering  71800.0
# 3  Polytechnic University of New York, Brooklyn  Engineering  62400.0
# 4                                  Cooper Union  Engineering  62200.0
#
#    mid_car25p  mid_car90p
# 0     99200.0    220000.0
# 1    104000.0         NaN
# 2     96000.0         NaN
# 3     94300.0    190000.0
# 4     80200.0         NaN

# %%
College_Type_clean.describe()
# Out:
#             str_sal     mid_car25p     mid_car90p
# count    269.000000     269.000000     231.000000
# mean   46068.401487   60373.234201  157705.627706
# std     6412.616242   11381.348857   34823.348157
# min    34800.000000   31800.000000   87600.000000
# 25%    42000.000000   53200.000000  136000.000000
# 50%    44700.000000   58400.000000  153000.000000
# 75%    48300.000000   65100.000000  170500.000000
# max    75500.000000  104000.000000  326000.000000

# %%
College_Type_df['School Name'].value_counts()
# Out:
# Louisiana State University (LSU)                     2
# University of Maryland, College Park                 2
# University of Georgia (UGA)                          2
# University of Alabama, Tuscaloosa                    2
# University of New Hampshire (UNH)                    2
# University of Florida (UF)                           2
# University of California, Santa Barbara (UCSB)       2
# Pennsylvania State University (PSU)                  2
# West Virginia University (WVU)                       2
# Randolph-Macon College                               2
# Indiana University (IU), Bloomington                 2
# University of Tennessee                              2
# Ohio University                                      2
# Arizona State University (ASU)                       2
# University of Illinois at Urbana-Champaign (UIUC)    2
# University of Texas (UT) - Austin                    2
# State University of New York (SUNY) at Albany        2
# Florida State University (FSU)                       2
# University of Iowa (UI)                              2
# University of Mississippi                            2
# University of Oklahoma                               1
# San Jose State University (SJSU)                     1
# University of Central Florida (UCF)                  1
# University of Texas at El Paso (UTEP)                1
# University of Arkansas - Monticello (UAM)            1
# University of California, Riverside (UCR)            1
# Southern Utah University                             1
# University of Texas at Arlington (UTA)               1
# South Dakota School of Mines & Technology            1
# Western Michigan University (WMU)                    1
#                                                     ..
# State University of New York (SUNY) at Fredonia      1
# University of Hawaii                                 1
# California State University (CSU), Chico             1
# Idaho State University                               1
# University of Colorado - Boulder (UCB)               1
# Rutgers University                                   1
# University of California, Santa Cruz (UCSC)          1
# University of Wisconsin (UW) - Green Bay             1
# Brown University                                     1
# Wellesley College                                    1
# Illinois State University                            1
# Colgate University                                   1
# Florida Atlantic University (FAU)                    1
# University of Wyoming (UW)                           1
# University of Arizona                                1
# University of Louisiana (UL) at Lafayette            1
# University of Arkansas                               1
# Arkansas State University (ASU)                      1
# University of Memphis (U of M)                       1
# Denison University                                   1
# California State University (CSU), Stanislaus        1
# University of Wisconsin (UW) - Platteville           1
# University of Nebraska                               1
# University of Illinois at Chicago                    1
# Wentworth Institute of Technology                    1
# Whitman College                                      1
# Colorado School of Mines                             1
# Wesleyan University (Middletown, Connecticut)        1
# Bates College                                        1
# Ball State University (BSU)                          1
# Name: School Name, Length: 249, dtype: int64

# %%
College_Type_df['School Type'].value_counts()
# Out:
# State           175
# Liberal Arts     47
# Party            20
# Engineering      19
# Ivy League        8
# Name: School Type, dtype: int64

# %%
College_Type_df_la = College_Type_clean.loc[College_Type_df['School Type'] == 'Liberal Arts', :]
College_Type_df_la.head()
# Out:
#             School Name   School Type  str_sal  mid_car25p  mid_car90p
# 39  Bucknell University  Liberal Arts  54100.0     80600.0    251000.0
# 40   Colgate University  Liberal Arts  52800.0     76700.0    265000.0
# 41      Amherst College  Liberal Arts  54500.0     84900.0         NaN
# 42    Lafayette College  Liberal Arts  53900.0     79300.0    204000.0
# 43      Bowdoin College  Liberal Arts  48100.0     74600.0         NaN

# %%
College_Type_df_la.describe()
# Out:
#             str_sal    mid_car25p     mid_car90p
# count     47.000000     47.000000      14.000000
# mean   45746.808511  61936.170213  191142.857143
# std     4368.854743  10368.648932   42413.454220
# min    38500.000000  42800.000000  120000.000000
# 25%    42250.000000  54900.000000  166000.000000
# 50%    45500.000000  60700.000000  187000.000000
# 75%    48600.000000  67300.000000  214000.000000
# max    54500.000000  84900.000000  265000.000000

# %%
College_Type_df_eng = College_Type_clean.loc[College_Type_df['School Type'] == 'Engineering', :]
College_Type_df_eng.head()
# Out:
#                                     School Name  School Type  str_sal  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering  72200.0
# 1      California Institute of Technology (CIT)  Engineering  75500.0
# 2                           Harvey Mudd College  Engineering  71800.0
# 3  Polytechnic University of New York, Brooklyn  Engineering  62400.0
# 4                                  Cooper Union  Engineering  62200.0
#
#    mid_car25p  mid_car90p
# 0     99200.0    220000.0
# 1    104000.0         NaN
# 2     96000.0         NaN
# 3     94300.0    190000.0
# 4     80200.0         NaN

# %%
College_Type_df_eng.describe()
# Out:
#             str_sal     mid_car25p     mid_car90p
# count     19.000000      19.000000      15.000000
# mean   59057.894737   81384.210526  173333.333333
# std     7842.924326   12418.143678   26794.633436
# min    46200.000000   62100.000000  121000.000000
# 25%    53250.000000   72700.000000  156000.000000
# 50%    58300.000000   81900.000000  180000.000000
# 75%    62000.000000   89550.000000  187500.000000
# max    75500.000000  104000.000000  220000.000000

# %%
x_axis = np.arange(len(College_Type_df_eng))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(15,5))

plt.scatter(College_Type_df_eng['School Name'], College_Type_df_eng['str_sal'], marker = 'o', s = 50)
plt.title("Engineering School Starting Salary", fontsize=25)
plt.ylabel('Salary ($)', fontsize = 20)

plt.xticks(tick_locations, College_Type_df_eng["School Name"], rotation="vertical", fontsize = 14)






plt.show()

# %%
x_axis = np.arange(len(College_Type_df_eng))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(15,5))

plt.scatter(College_Type_df_eng['School Name'], College_Type_df_eng['mid_car25p'], marker = 'o', s = 50)
plt.title("Engineering School Mid-Career Salary", fontsize=25)
plt.ylabel('Salary ($)', fontsize = 20)

plt.xticks(tick_locations, College_Type_df_eng["School Name"], rotation="vertical", fontsize = 14)






plt.show()

# %%
x_axis = np.arange(len(College_Type_df_eng))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(15,5))

plt.scatter(College_Type_df_eng['School Name'], College_Type_df_eng['mid_car90p'], marker = 'o', s = 50)
plt.title("Engineering School End Career Salary", fontsize=25)
plt.ylabel('Salary ($)', fontsize = 20)

plt.xticks(tick_locations, College_Type_df_eng["School Name"], rotation="vertical", fontsize = 14)






plt.show()

# %%
College_Type_df_eng.plot(kind="bar", fontsize=20, figsize=(12,7))

# Set a title for the chart
plt.title("School by Type", fontsize=35)
plt.xticks(tick_locations, College_Type_df_eng["School Name"], rotation="vertical", fontsize = 14)


plt.show()
plt.tight_layout()

# %%
College_Type_df_party = College_Type_clean.loc[College_Type_df['School Type'] == 'Party', :]
College_Type_df_party.head()
# Out:
#                                           School Name School Type  str_sal  \
# 19  University of Illinois at Urbana-Champaign (UIUC)       Party  52900.0
# 20               University of Maryland, College Park       Party  52000.0
# 21     University of California, Santa Barbara (UCSB)       Party  50500.0
# 22                  University of Texas (UT) - Austin       Party  49700.0
# 23      State University of New York (SUNY) at Albany       Party  44500.0
#
#     mid_car25p  mid_car90p
# 19     68900.0    177000.0
# 20     68300.0    166000.0
# 21     71200.0    173000.0
# 22     67400.0    188000.0
# 23     63100.0    209000.0

# %%
x_axis = np.arange(len(College_Type_df_party))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(15,5))

plt.scatter(College_Type_df_party['School Name'], College_Type_df_party['str_sal'], marker = 'o', s = 50)
plt.title("Party School Starting Salary", fontsize=25)
plt.ylabel('Salary')

plt.xticks(tick_locations, College_Type_df_party["School Name"], rotation="vertical", fontsize = 14)





plt.show()

# %%
College_Type_df_party.plot(kind="bar", fontsize=20, figsize=(15,5))

# Set a title for the chart
plt.title("School by Type", fontsize=35)
plt.xticks(tick_locations, College_Type_df_party["School Name"], rotation="vertical", fontsize = 14)


plt.show()
plt.tight_layout()

# %%
x_axis = np.arange(len(College_Type_df_party))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(15,5))

plt.scatter(College_Type_df_party['School Name'], College_Type_df_party['str_sal'], marker = 'o', s = 50)



plt.xticks(tick_locations, College_Type_df_party["School Name"], rotation="vertical", fontsize = 14)


plt.title("Party School Starting Salary", fontsize=25)





plt.show()

# %%
x_axis = np.arange(len(College_Type_df_party))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(15,5))

plt.scatter(College_Type_df_party['School Name'], College_Type_df_party['mid_car25p'], marker = 'o', s = 50)



plt.xticks(tick_locations, College_Type_df_party["School Name"], rotation="vertical", fontsize = 14)


plt.title("Party School Starting Salary", fontsize=25)





plt.show()

# %%
College_Type_df_party.dtypes
# Out:
# School Name     object
# School Type     object
# str_sal        float64
# mid_car25p     float64
# mid_car90p     float64
# dtype: object

# %%
College_Type_df_party.describe()
# Out:
#            str_sal    mid_car25p     mid_car90p
# count     20.00000     20.000000      19.000000
# mean   45715.00000  60005.000000  166947.368421
# std     3685.71567   5755.498515   16091.659966
# min    41300.00000  52800.000000  141000.000000
# 25%    42500.00000  55300.000000  158000.000000
# 50%    44600.00000  60550.000000  164000.000000
# 75%    47975.00000  62950.000000  175000.000000
# max    52900.00000  71200.000000  209000.000000

# %%
College_Type_df_State = College_Type_clean.loc[College_Type_df['School Type'] == 'State', :]
College_Type_df_State.head()
# Out:
#                                        School Name School Type  str_sal  \
# 94              University of California, Berkeley       State  59900.0
# 95                    University of Virginia (UVA)       State  52700.0
# 96                        Cal Poly San Luis Obispo       State  57200.0
# 97  University of California at Los Angeles (UCLA)       State  52600.0
# 98      University of California, San Diego (UCSD)       State  51100.0
#
#     mid_car25p  mid_car90p
# 94     81000.0    201000.0
# 95     71800.0    215000.0
# 96     74700.0    178000.0
# 97     72500.0    193000.0
# 98     75400.0    177000.0

# %%
x_axis = np.arange(len(College_Type_df_State))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(15,5))

plt.scatter(College_Type_df_State['School Name'], College_Type_df_State['str_sal'], marker = 'o', s = 50)
plt.title("State School Starting Salary", fontsize=25)


plt.xticks(tick_locations, College_Type_df_State["School Name"], rotation="vertical", fontsize = 14)






plt.show()
plt.tight_layout()

# %%
College_Type_df_State.plot(kind="bar", fontsize=20, figsize=(15,5))

# Set a title for the chart
plt.title("State Schools", fontsize=35)
plt.xticks(tick_locations, College_Type_df_State["School Name"], rotation="vertical", fontsize = 14)


plt.show()
plt.tight_layout()

# %%
College_Type_df_State.describe()
# Out:
#             str_sal    mid_car25p     mid_car90p
# count    175.000000    175.000000     175.000000
# mean   44126.285714  56689.714286  147571.428571
# std     4269.067495   7910.258684   22642.391981
# min    34800.000000  31800.000000   87600.000000
# 25%    41400.000000  51600.000000  132000.000000
# 50%    43600.000000  56200.000000  147000.000000
# 75%    46300.000000  61350.000000  161500.000000
# max    59900.000000  81000.000000  215000.000000

# %%
College_Type_df_Ivy = College_Type_clean.loc[College_Type_df['School Type'] == 'Ivy League']
College_Type_df_Ivy
# Out:
#                    School Name School Type  str_sal  mid_car25p  mid_car90p
# 86           Dartmouth College  Ivy League  58000.0     90200.0    321000.0
# 87        Princeton University  Ivy League  66500.0    100000.0    261000.0
# 88             Yale University  Ivy League  59100.0     80600.0    326000.0
# 89          Harvard University  Ivy League  63400.0     86200.0    288000.0
# 90  University of Pennsylvania  Ivy League  60900.0     79200.0    282000.0
# 91          Cornell University  Ivy League  60300.0     79800.0    210000.0
# 92            Brown University  Ivy League  56200.0     74400.0    228000.0
# 93         Columbia University  Ivy League  59400.0     71900.0    241000.0

# %%
x_axis = np.arange(len(College_Type_df_Ivy))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(8,5))

plt.scatter(College_Type_df_Ivy['School Name'], College_Type_df_Ivy['str_sal'], marker = 'o', s = 50)
plt.title("Ivy League School Starting Salary", fontsize=25)


plt.xticks(tick_locations, College_Type_df_Ivy["School Name"], rotation="vertical", fontsize = 14)






plt.show()
plt.tight_layout()

# %%
College_Type_df_Ivy.plot(kind="bar", fontsize=20, figsize = (8,6))

# Set a title for the chart
plt.title("School by Type", fontsize=35)
plt.xticks(tick_locations, College_Type_df_Ivy["School Name"], rotation="vertical", fontsize = 14)



plt.show()

# %%
College_Type_df_Ivy.describe()
# Out:
#             str_sal     mid_car25p     mid_car90p
# count      8.000000       8.000000       8.000000
# mean   60475.000000   82787.500000  269625.000000
# std     3218.584427    9089.466038   42240.594896
# min    56200.000000   71900.000000  210000.000000
# 25%    58825.000000   78000.000000  237750.000000
# 50%    59850.000000   80200.000000  271500.000000
# 75%    61525.000000   87200.000000  296250.000000
# max    66500.000000  100000.000000  326000.000000

# %%
College_Type_sort_df = College_Type_df.sort_values('School Type')
College_Type_sort_df.head()
# Out:
#                                           School Name  School Type  str_sal  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering  72200.0
# 18                 Tennessee Technological University  Engineering  46200.0
# 17        Embry-Riddle Aeronautical University (ERAU)  Engineering  52700.0
# 16            Rochester Institute of Technology (RIT)  Engineering  48900.0
# 15  New Mexico Institute of Mining and Technology ...  Engineering  51000.0
#
#      mid_car  mid_car_10p  mid_car25p  mid_car75p  mid_car90p
# 0   126000.0      76800.0     99200.0    168000.0    220000.0
# 18   80000.0      42100.0     62600.0     99500.0    121000.0
# 17   80700.0      49800.0     64000.0    106000.0    142000.0
# 16   84600.0      45000.0     62100.0    112000.0    159000.0
# 15   93400.0          NaN     67400.0    123000.0         NaN

# %%
# Create a boxplot to compare means Starting Salary
College_Type_sort_df.boxplot("str_sal", by="School Type", figsize=(15,6), fontsize=15, patch_artist=True)
plt.title("")


# get rid of the automatic 'Boxplot grouped by group_by_column_name' title
plt.suptitle("Starting Salary by Type", fontsize=30)

plt.ylabel('Salary', fontsize=20)

plt.xlabel('School Type', fontsize=20)

plt.show()

# %%
str_grp_1 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Engineering']['str_sal']
str_grp_2 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Ivy League']['str_sal']
str_grp_3 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Liberal Arts']['str_sal']
str_grp_4 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Party']['str_sal']
str_grp_5 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'State']['str_sal']

# %%
stats.f_oneway(str_grp_1,str_grp_2,str_grp_3,str_grp_4,str_grp_5)
# Out:
# F_onewayResult(statistic=66.56143762415526, pvalue=7.056857278200541e-39)

# %%
# Create a boxplot to compare means Starting Salary
College_Type_sort_df.boxplot("mid_car25p", by="School Type", figsize=(15,6), fontsize=15, patch_artist= True)
plt.title("")


# get rid of the automatic 'Boxplot grouped by group_by_column_name' title
plt.suptitle("Mid 25th Salary by Type", fontsize=30)

plt.ylabel('Salary', fontsize=20)

plt.xlabel('School Type', fontsize=20)

plt.show()

# %%
mid25_grp_1 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Engineering']['mid_car25p']
mid25_grp_2 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Ivy League']['mid_car25p']
mid25_grp_3 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Liberal Arts']['mid_car25p']
mid25_grp_4 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Party']['mid_car25p']
mid25_grp_5 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'State']['mid_car25p']

# %%
stats.f_oneway(mid25_grp_1,mid25_grp_2,mid25_grp_3,mid25_grp_4,mid25_grp_5)
# Out:
# F_onewayResult(statistic=49.62182745545388, pvalue=4.1624416178425265e-31)

# %%
# Create a boxplot to compare means Starting Salary
College_Type_sort_df.boxplot("mid_car90p", by="School Type", figsize=(15,6), fontsize=15, patch_artist=True)
plt.title("")


# get rid of the automatic 'Boxplot grouped by group_by_column_name' title
plt.suptitle("Mid 90th Salary by Type", fontsize=30)

plt.ylabel('Salary', fontsize=20)

plt.xlabel('School Type', fontsize=20)

plt.show()

# %%
mid90_grp_1 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Engineering']['mid_car90p']
mid90_grp_2 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Ivy League']['mid_car90p']
mid90_grp_3 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Liberal Arts']['mid_car90p']
mid90_grp_4 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'Party']['mid_car90p']
mid90_grp_5 = College_Type_sort_df[College_Type_sort_df['School Type'] == 'State']['mid_car90p']

# %%
stats.f_oneway(mid90_grp_1,mid90_grp_2,mid90_grp_3,mid90_grp_4,mid90_grp_5)
# Out:
# F_onewayResult(statistic=nan, pvalue=nan)

# %%
College_Type_df_party.mean()
# Out:
# str_sal        45715.000000
# mid_car25p     60005.000000
# mid_car90p    166947.368421
# dtype: float64

# %%
College_Type_df_Ivy.mean()
# Out:
# str_sal        60475.0
# mid_car25p     82787.5
# mid_car90p    269625.0
# dtype: float64

# %%
College_Type_df_State.mean()
# Out:
# str_sal        44126.285714
# mid_car25p     56689.714286
# mid_car90p    147571.428571
# dtype: float64

# %%
College_Type_df_la.mean()
# Out:
# str_sal        45746.808511
# mid_car25p     61936.170213
# mid_car90p    191142.857143
# dtype: float64

# %%
College_Type_df_eng.mean()
# Out:
# str_sal        59057.894737
# mid_car25p     81384.210526
# mid_car90p    173333.333333
# dtype: float64

# %%
stats.ttest_ind(College_Type_df_eng.str_sal, College_Type_df_Ivy.str_sal, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.6656410541408333, pvalue=0.511736896647387)
