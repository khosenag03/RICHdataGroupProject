# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import scipy.stats as stats

# %%
#Read the income return on the type of degree CSV
Degrees_Payback = pd.read_csv('degrees-that-pay-back.csv')
Degree_df = pd.DataFrame(Degrees_Payback)

#Ready the salary averages based on college type
Salary_By_College = pd.read_csv('salaries-by-college-type.csv')
College_Salary_df = pd.DataFrame(Salary_By_College)

#Read the income based upon region
Salary_By_Region = pd.read_csv('salaries-by-region.csv')
Region_Salary_df = pd.DataFrame(Salary_By_Region)

# %%
Region_Salary_df.head()
# Out:
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0            $70,400.00              $129,000.00
# 1            $75,500.00              $123,000.00
# 2            $71,800.00              $122,000.00
# 3            $59,900.00              $112,000.00
# 4            $51,900.00              $105,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                       $68,400.00                        $93,100.00
# 1                               NaN                      $104,000.00
# 2                               NaN                       $96,000.00
# 3                       $59,500.00                        $81,000.00
# 4                               NaN                       $54,800.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                      $184,000.00                       $257,000.00
# 1                      $161,000.00                                NaN
# 2                      $180,000.00                                NaN
# 3                      $149,000.00                       $201,000.00
# 4                      $157,000.00                                NaN

# %%
#Check for duplicate rows and create a column for duplicate Rows in DF (There were non)
Region_Salary_df["Is_Duplicated"]= Region_Salary_df.duplicated()
Region_Salary_df.head()

#Removing Duplicate Rows if there were any
#Region_Salary_df = Region_Salary_df.drop_duplicates()
#Region_Salary_df
# Out:
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0            $70,400.00              $129,000.00
# 1            $75,500.00              $123,000.00
# 2            $71,800.00              $122,000.00
# 3            $59,900.00              $112,000.00
# 4            $51,900.00              $105,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                       $68,400.00                        $93,100.00
# 1                               NaN                      $104,000.00
# 2                               NaN                       $96,000.00
# 3                       $59,500.00                        $81,000.00
# 4                               NaN                       $54,800.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary  \
# 0                      $184,000.00                       $257,000.00
# 1                      $161,000.00                                NaN
# 2                      $180,000.00                                NaN
# 3                      $149,000.00                       $201,000.00
# 4                      $157,000.00                                NaN
#
#    Is_Duplicated
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
#Rename the columns
Region_Salary_df.columns = ['School Name', 'Region', 'Starting_Mid', 'Mid_Sal', 'Mid_10th', 'Mid_25th', 'Mid_75th', 'Mid_90th','Is_Duplicated']
Region_Salary_df.head()
# Out:
#                                 School Name      Region Starting_Mid  \
# 0                       Stanford University  California  $70,400.00
# 1  California Institute of Technology (CIT)  California  $75,500.00
# 2                       Harvey Mudd College  California  $71,800.00
# 3        University of California, Berkeley  California  $59,900.00
# 4                        Occidental College  California  $51,900.00
#
#         Mid_Sal     Mid_10th      Mid_25th      Mid_75th      Mid_90th  \
# 0  $129,000.00   $68,400.00    $93,100.00   $184,000.00   $257,000.00
# 1  $123,000.00           NaN  $104,000.00   $161,000.00            NaN
# 2  $122,000.00           NaN   $96,000.00   $180,000.00            NaN
# 3  $112,000.00   $59,500.00    $81,000.00   $149,000.00   $201,000.00
# 4  $105,000.00           NaN   $54,800.00   $157,000.00            NaN
#
#    Is_Duplicated
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
#Create list for loop
Dollar_Cols = ['Starting_Mid', 'Mid_Sal', 'Mid_10th', 'Mid_25th', 'Mid_75th', 'Mid_90th']

#Loop through DF and convert columns with Dollar $ign (objects) to numeric values (integer)
for x in Dollar_Cols:
    Region_Salary_df[x] = Region_Salary_df[x].str.replace("$","")
    Region_Salary_df[x] = Region_Salary_df[x].str.replace(",","")
    Region_Salary_df[x] = pd.to_numeric(Region_Salary_df[x])

Region_Salary_df.head()
# Out:
#                                 School Name      Region  Starting_Mid  \
# 0                       Stanford University  California       70400.0
# 1  California Institute of Technology (CIT)  California       75500.0
# 2                       Harvey Mudd College  California       71800.0
# 3        University of California, Berkeley  California       59900.0
# 4                        Occidental College  California       51900.0
#
#     Mid_Sal  Mid_10th  Mid_25th  Mid_75th  Mid_90th  Is_Duplicated
# 0  129000.0   68400.0   93100.0  184000.0  257000.0          False
# 1  123000.0       NaN  104000.0  161000.0       NaN          False
# 2  122000.0       NaN   96000.0  180000.0       NaN          False
# 3  112000.0   59500.0   81000.0  149000.0  201000.0          False
# 4  105000.0       NaN   54800.0  157000.0       NaN          False

# %%
#Sort DF by Regions with the Highest to lowest 'Starting_Mid' Salaries
Region_Sort = Region_Salary_df.sort_values(['Region', 'Starting_Mid'], ascending=[True, False])
Region_Sort.head()
# Out:
#                                 School Name      Region  Starting_Mid  \
# 1  California Institute of Technology (CIT)  California       75500.0
# 2                       Harvey Mudd College  California       71800.0
# 0                       Stanford University  California       70400.0
# 3        University of California, Berkeley  California       59900.0
# 5                  Cal Poly San Luis Obispo  California       57200.0
#
#     Mid_Sal  Mid_10th  Mid_25th  Mid_75th  Mid_90th  Is_Duplicated
# 1  123000.0       NaN  104000.0  161000.0       NaN          False
# 2  122000.0       NaN   96000.0  180000.0       NaN          False
# 0  129000.0   68400.0   93100.0  184000.0  257000.0          False
# 3  112000.0   59500.0   81000.0  149000.0  201000.0          False
# 5  101000.0   55000.0   74700.0  133000.0  178000.0          False

# %%
# Create a boxplot to compare means Starting Salary
Region_Sort.boxplot("Starting_Mid", by="Region", figsize=(15,6), fontsize=15, patch_artist=True)
plt.title("")


# get rid of the automatic 'Boxplot grouped by group_by_column_name' title
plt.suptitle("Average Starting Salary by Region", fontsize=30)

plt.ylabel('Salary', fontsize=20)

plt.xlabel('Region', fontsize=20)

plt.show()

# Save the figure
plt.savefig("StartingSalMeanByRegion.png")

# %%
# Create a boxplot to compare means Mid_25th Salary
Region_Sort.boxplot("Mid_25th", by="Region", figsize=(15,6), fontsize=15, patch_artist=True)

plt.title("")

# get rid of the automatic 'Boxplot grouped by group_by_column_name' title
plt.suptitle("75% of Population Earnings at Mid-Career", fontsize=30)

plt.ylabel('Salary', fontsize=20)

plt.xlabel('Region', fontsize=20)

plt.show()

# Save the figure
plt.savefig("Mid25thSalaryByRegion.png")

# %%
# Create a boxplot to compare means Mid_90th Salary
Region_Sort.boxplot(by=["Region"], column=["Mid_90th"], figsize=(15,6), fontsize=15, patch_artist=True)

plt.title("")

# get rid of the automatic 'Boxplot grouped by group_by_column_name' title
plt.suptitle("Top 10% of Population Earnings by Mid Career", fontsize=30)

plt.ylabel('Salary', fontsize=20)

plt.xlabel('Region', fontsize=20)

plt.show()

plt.savefig("Mid90thSalaryByRegion.png")

# %%
df = Region_Sort[['Starting_Mid','Mid_25th','Mid_90th','Region']]
var = df.groupby('Region').mean()
var.plot(kind='line', figsize=(15,6), fontsize=15,);

#Title
plt.suptitle("Comparison of Regions Salaries within Percentiles", fontsize=30)

plt.savefig("ComparingRegionSalPercentiles.png")

# %%
#Extract data by Region from the Master DF
Cali_Region = Region_Salary_df.loc[Region_Salary_df["Region"] == "California", :]
Cali_Region.head()

#List salary change over the lenght of mid-career by region; from school with hightest Starting_Mid to lowest Mid_90th
Cali_Sort = Cali_Region.sort_values(['Starting_Mid', 'School Name'], ascending=[False, True])
Cali_Sort.head()
# Out:
#                                 School Name      Region  Starting_Mid  \
# 1  California Institute of Technology (CIT)  California       75500.0
# 2                       Harvey Mudd College  California       71800.0
# 0                       Stanford University  California       70400.0
# 3        University of California, Berkeley  California       59900.0
# 5                  Cal Poly San Luis Obispo  California       57200.0
#
#     Mid_Sal  Mid_10th  Mid_25th  Mid_75th  Mid_90th  Is_Duplicated
# 1  123000.0       NaN  104000.0  161000.0       NaN          False
# 2  122000.0       NaN   96000.0  180000.0       NaN          False
# 0  129000.0   68400.0   93100.0  184000.0  257000.0          False
# 3  112000.0   59500.0   81000.0  149000.0  201000.0          False
# 5  101000.0   55000.0   74700.0  133000.0  178000.0          False

# %%
#Give a description of the salary data by region.
Cali_Region.describe()
# Out:
#        Starting_Mid        Mid_Sal      Mid_10th       Mid_25th  \
# count     28.000000      28.000000     22.000000      28.000000
# mean   51032.142857   93132.142857  47777.272727   67153.571429
# std     8982.041901   15787.713309   7818.106689   13791.583105
# min    38000.000000   67500.000000  30800.000000   44600.000000
# 25%    45650.000000   83675.000000  45175.000000   59825.000000
# 50%    48450.000000   91550.000000  47100.000000   62750.000000
# 75%    52825.000000  101000.000000  51300.000000   72825.000000
# max    75500.000000  129000.000000  68400.000000  104000.000000
#
#             Mid_75th       Mid_90th
# count      28.000000      22.000000
# mean   127350.000000  167909.090909
# std     24665.157611   29931.523581
# min     92200.000000  117000.000000
# 25%    112500.000000  154000.000000
# 50%    122000.000000  158000.000000
# 75%    139250.000000  177750.000000
# max    184000.000000  257000.000000

# %%
Western_Region = Region_Salary_df.loc[Region_Salary_df["Region"] == "Western", :]
Western_Region.head()

#List salary change over the lenght of mid-career by region; from school with hightest Starting_Mid to lowest Mid_90th
Western_Sort = Western_Region.sort_values(['Starting_Mid', 'School Name'], ascending=[False, True])
Western_Sort.head()
# Out:
#                                           School Name   Region  Starting_Mid  \
# 28                           Colorado School of Mines  Western       58100.0
# 30  New Mexico Institute of Mining and Technology ...  Western       51000.0
# 31                     Brigham Young University (BYU)  Western       49400.0
# 33                      University of Washington (UW)  Western       48800.0
# 56                                   Regis University  Western       48300.0
#
#      Mid_Sal  Mid_10th  Mid_25th  Mid_75th  Mid_90th  Is_Duplicated
# 28  106000.0   62200.0   87900.0  142000.0  201000.0          False
# 30   93400.0       NaN   67400.0  123000.0       NaN          False
# 31   88600.0   50600.0   68500.0  119000.0  164000.0          False
# 33   85300.0   47000.0   59800.0  115000.0  149000.0          False
# 56   73800.0   41000.0   55500.0   94800.0  117000.0          False

# %%
Western_Sort.describe()
# Out:
#        Starting_Mid        Mid_Sal      Mid_10th      Mid_25th       Mid_75th  \
# count     42.000000      42.000000     34.000000     42.000000      42.000000
# mean   44414.285714   78200.000000  42985.294118  56580.952381  106026.190476
# std     3935.180377    9743.740955   5473.192651   9008.078707   14107.169247
# min    37300.000000   50600.000000  35400.000000  31800.000000   78400.000000
# 25%    42050.000000   72600.000000  39200.000000  52650.000000   99225.000000
# 50%    44850.000000   78850.000000  41700.000000  56650.000000  104000.000000
# 75%    46575.000000   83125.000000  46000.000000  60025.000000  113000.000000
# max    58100.000000  106000.000000  62200.000000  87900.000000  148000.000000
#
#             Mid_90th
# count      34.000000
# mean   143823.529412
# std     20338.753259
# min    110000.000000
# 25%    131250.000000
# 50%    142500.000000
# 75%    150000.000000
# max    201000.000000

# %%
#Extract data by Region from the Master DF
Northeastern_Region = Region_Salary_df.loc[Region_Salary_df["Region"] == "Northeastern", :]
Northeastern_Region.head()

#List salary change over the lenght of mid-career by region; from school with hightest Starting_Mid to lowest Mid_90th
Northeastern_Sort = Northeastern_Region.sort_values(['Starting_Mid', 'School Name'], ascending=[False, True])
Northeastern_Sort.head()
# Out:
#                                       School Name        Region  Starting_Mid  \
# 222   Massachusetts Institute of Technology (MIT)  Northeastern       72200.0
# 221                          Princeton University  Northeastern       66500.0
# 224                            Harvard University  Northeastern       63400.0
# 226  Polytechnic University of New York, Brooklyn  Northeastern       62400.0
# 227                                  Cooper Union  Northeastern       62200.0
#
#       Mid_Sal  Mid_10th  Mid_25th  Mid_75th  Mid_90th  Is_Duplicated
# 222  126000.0   76800.0   99200.0  168000.0  220000.0          False
# 221  131000.0   68900.0  100000.0  190000.0  261000.0          False
# 224  124000.0   54800.0   86200.0  179000.0  288000.0          False
# 226  114000.0   66800.0   94300.0  143000.0  190000.0          False
# 227  114000.0       NaN   80200.0  142000.0       NaN          False

# %%
Northeastern_Sort.describe()
# Out:
#        Starting_Mid        Mid_Sal      Mid_10th       Mid_25th  \
# count    100.000000     100.000000     82.000000     100.000000
# mean   48496.000000   91352.000000  49101.219512   65479.000000
# std     7159.001115   15103.023177   9873.714874   11808.816215
# min    36900.000000   62600.000000  32800.000000   42800.000000
# 25%    43150.000000   80825.000000  42875.000000   57325.000000
# 50%    47000.000000   88700.000000  47050.000000   62800.000000
# 75%    52825.000000  101250.000000  53825.000000   72050.000000
# max    72200.000000  134000.000000  80000.000000  100000.000000
#
#             Mid_75th       Mid_90th
# count     100.000000      82.000000
# mean   129576.000000  181926.829268
# std     25988.995807   42439.144663
# min     85700.000000  117000.000000
# 25%    111500.000000  151500.000000
# 50%    125500.000000  173500.000000
# 75%    143000.000000  197250.000000
# max    234000.000000  326000.000000

# %%
#Extract data by Region from the Master DF
Midwestern_Region = Region_Salary_df.loc[Region_Salary_df["Region"] == "Midwestern", :]
Midwestern_Region.head()

#List salary change over the lenght of mid-career by region; from school with hightest Starting_Mid to lowest Mid_90th
Midwestern_Sort = Midwestern_Region.sort_values(['Starting_Mid', 'School Name'], ascending=[False, True])
Midwestern_Sort.head()
# Out:
#                                   School Name      Region  Starting_Mid  \
# 77       University of Missouri - Rolla (UMR)  Midwestern       57100.0
# 70                   University of Notre Dame  Midwestern       56300.0
# 74            Case Western Reserve University  Midwestern       56200.0
# 73     Illinois Institute of Technology (IIT)  Midwestern       56000.0
# 78  South Dakota School of Mines & Technology  Midwestern       55800.0
#
#      Mid_Sal  Mid_10th  Mid_25th  Mid_75th  Mid_90th  Is_Duplicated
# 77   95800.0   67600.0   80400.0  122000.0  166000.0          False
# 70  116000.0   66400.0   85100.0  163000.0  235000.0          False
# 74   96500.0   54900.0   76500.0  123000.0  168000.0          False
# 73   97800.0   56100.0   77400.0  121000.0  165000.0          False
# 78   93400.0   71500.0   81900.0  122000.0  147000.0          False

# %%
Midwestern_Sort.describe()
# Out:
#        Starting_Mid        Mid_Sal      Mid_10th      Mid_25th       Mid_75th  \
# count     71.000000      71.000000     64.000000     71.000000      71.000000
# mean   44225.352113   78180.281690  43076.562500  57026.760563  107594.366197
# std     5068.240560   12997.687923   8438.267749  10379.911337   19125.501953
# min    35300.000000   43900.000000  25600.000000  32200.000000   60900.000000
# 25%    41100.000000   70850.000000  37850.000000  49650.000000   95550.000000
# 50%    43100.000000   77800.000000  40600.000000  54400.000000  105000.000000
# 75%    46250.000000   84700.000000  46275.000000  61800.000000  119000.000000
# max    57100.000000  116000.000000  71500.000000  85100.000000  174000.000000
#
#             Mid_90th
# count      64.000000
# mean   147689.062500
# std     28818.331452
# min     85700.000000
# 25%    128000.000000
# 50%    143000.000000
# 75%    162250.000000
# max    255000.000000

# %%
#Extract data by Region from the Master DF
Southern_Region = Region_Salary_df.loc[Region_Salary_df["Region"] == "Southern", :]
Southern_Region.head()

#List salary change over the lenght of mid-career by region; from school with hightest Starting_Mid to lowest Mid_90th
Southern_Sort = Southern_Region.sort_values(['Starting_Mid', 'School Name'], ascending=[False, True])
Southern_Sort.head()
# Out:
#                          School Name    Region  Starting_Mid   Mid_Sal  \
# 141                  Rice University  Southern       64000.0  110000.0
# 143                  Duke University  Southern       58900.0  106000.0
# 144  Georgia Institute of Technology  Southern       58300.0  106000.0
# 142            Georgetown University  Southern       55000.0  110000.0
# 145    Washington and Lee University  Southern       53600.0  104000.0
#
#      Mid_10th  Mid_25th  Mid_75th  Mid_90th  Is_Duplicated
# 141   55900.0   82100.0  141000.0  216000.0          False
# 143   56000.0   77400.0  149000.0  218000.0          False
# 144   67200.0   85200.0  137000.0  183000.0          False
# 142   60300.0   85800.0  174000.0  248000.0          False
# 145       NaN   82800.0  146000.0       NaN          False

# %%
Southern_Sort.describe()
# Out:
#        Starting_Mid        Mid_Sal      Mid_10th      Mid_25th       Mid_75th  \
# count     79.000000      79.000000     71.000000     79.000000      79.000000
# mean   44521.518987   79505.063291  43074.647887  57506.329114  109662.025316
# std     5626.099229   14067.592314   6675.642683  10489.046078   20865.701852
# min    34500.000000   51000.000000  32100.000000  36800.000000   70400.000000
# 25%    41100.000000   70400.000000  38850.000000  50400.000000   97600.000000
# 50%    43400.000000   79400.000000  42300.000000  56500.000000  107000.000000
# 75%    47050.000000   87850.000000  46350.000000  62800.000000  121000.000000
# max    64000.000000  110000.000000  67200.000000  85800.000000  174000.000000
#
#             Mid_90th
# count      71.000000
# mean   152769.014085
# std     32587.980219
# min     91300.000000
# 25%    129500.000000
# 50%    150000.000000
# 75%    168000.000000
# max    248000.000000

# %%
#Find the mean for each period of Salary change and groupby the Region names
Region_df = Region_Sort.groupby('Region', as_index=False)['Starting_Mid','Mid_Sal','Mid_10th', 'Mid_25th', 'Mid_75th', 'Mid_90th'].mean()
Region_df
# Out:
#          Region  Starting_Mid       Mid_Sal      Mid_10th      Mid_25th  \
# 0    California  51032.142857  93132.142857  47777.272727  67153.571429
# 1    Midwestern  44225.352113  78180.281690  43076.562500  57026.760563
# 2  Northeastern  48496.000000  91352.000000  49101.219512  65479.000000
# 3      Southern  44521.518987  79505.063291  43074.647887  57506.329114
# 4       Western  44414.285714  78200.000000  42985.294118  56580.952381
#
#         Mid_75th       Mid_90th
# 0  127350.000000  167909.090909
# 1  107594.366197  147689.062500
# 2  129576.000000  181926.829268
# 3  109662.025316  152769.014085
# 4  106026.190476  143823.529412

# %%
# Find the number of schools in each Region
School_Count_by_Region = Region_Salary_df['Region'].value_counts()
School_Count_by_Region
# Out:
# Northeastern    100
# Southern         79
# Midwestern       71
# Western          42
# California       28
# Name: Region, dtype: int64

# %%
x_axis = np.arange(len(School_Count_by_Region))

# Use DataFrame.plot() in order to create a bar chart of the data
School_Count_by_Region.plot(kind="bar", fontsize=20, figsize=(15,6))

# Set a title for the chart
plt.title("Number of Schools by Region", fontsize=35)

plt.bar(x_axis, School_Count_by_Region, alpha=1, color=['red','orange','yellow','green','blue'])

plt.xlabel("Region", fontsize=25)

plt.ylabel("Number of Schools", fontsize=25)

# Sets the y limits of the current chart
plt.ylim(0, max(School_Count_by_Region)+50)

plt.show()

plt.savefig("NumberOfSchoolsByRegion.png")

# %%
#Create new DF that Sorts Region_df by Hightest to Lowest 'Starting_Mid'
Region_by_Start_Mid = Region_df.sort_values('Starting_Mid', ascending=False)
Region_by_Start_Mid
# Out:
#          Region  Starting_Mid       Mid_Sal      Mid_10th      Mid_25th  \
# 0    California  51032.142857  93132.142857  47777.272727  67153.571429
# 2  Northeastern  48496.000000  91352.000000  49101.219512  65479.000000
# 3      Southern  44521.518987  79505.063291  43074.647887  57506.329114
# 4       Western  44414.285714  78200.000000  42985.294118  56580.952381
# 1    Midwestern  44225.352113  78180.281690  43076.562500  57026.760563
#
#         Mid_75th       Mid_90th
# 0  127350.000000  167909.090909
# 2  129576.000000  181926.829268
# 3  109662.025316  152769.014085
# 4  106026.190476  143823.529412
# 1  107594.366197  147689.062500

# %%
#Create new DF that Sorts Region_df by Hightest to Lowest 'Mid_75th'
Region_75th_Sal = Region_df.sort_values('Mid_75th', ascending=False)
Region_75th_Sal
# Out:
#          Region  Starting_Mid       Mid_Sal      Mid_10th      Mid_25th  \
# 2  Northeastern  48496.000000  91352.000000  49101.219512  65479.000000
# 0    California  51032.142857  93132.142857  47777.272727  67153.571429
# 3      Southern  44521.518987  79505.063291  43074.647887  57506.329114
# 1    Midwestern  44225.352113  78180.281690  43076.562500  57026.760563
# 4       Western  44414.285714  78200.000000  42985.294118  56580.952381
#
#         Mid_75th       Mid_90th
# 2  129576.000000  181926.829268
# 0  127350.000000  167909.090909
# 3  109662.025316  152769.014085
# 1  107594.366197  147689.062500
# 4  106026.190476  143823.529412

# %%
#Create new DF that Sorts Region_df by Hightest to Lowest 'Mid_90th'
Region_90th_Sal = Region_df.sort_values('Mid_90th', ascending=False)
Region_90th_Sal
# Out:
#          Region  Starting_Mid       Mid_Sal      Mid_10th      Mid_25th  \
# 2  Northeastern  48496.000000  91352.000000  49101.219512  65479.000000
# 0    California  51032.142857  93132.142857  47777.272727  67153.571429
# 3      Southern  44521.518987  79505.063291  43074.647887  57506.329114
# 1    Midwestern  44225.352113  78180.281690  43076.562500  57026.760563
# 4       Western  44414.285714  78200.000000  42985.294118  56580.952381
#
#         Mid_75th       Mid_90th
# 2  129576.000000  181926.829268
# 0  127350.000000  167909.090909
# 3  109662.025316  152769.014085
# 1  107594.366197  147689.062500
# 4  106026.190476  143823.529412

# %%
#Create groups for Analysis of Variances to test the differences between the Starting Means of the Regions
Salary_Mid_Gr1 = Region_Salary_df[Region_Salary_df['Region'] == 'Northeastern']['Starting_Mid']
Salary_Mid_Gr2 = Region_Salary_df[Region_Salary_df['Region'] == 'California']['Starting_Mid']
Salary_Mid_Gr3 = Region_Salary_df[Region_Salary_df['Region'] == 'Southern']['Starting_Mid']
Salary_Mid_Gr4 = Region_Salary_df[Region_Salary_df['Region'] == 'Midwestern']['Starting_Mid']
Salary_Mid_Gr5 = Region_Salary_df[Region_Salary_df['Region'] == 'Western']['Starting_Mid']

#Perform Analysis of Variance (ANOVA) test
stats.f_oneway(Salary_Mid_Gr1, Salary_Mid_Gr2, Salary_Mid_Gr3, Salary_Mid_Gr4, Salary_Mid_Gr5)
# Out:
# F_onewayResult(statistic=11.749409362366825, pvalue=6.593949101708314e-09)
